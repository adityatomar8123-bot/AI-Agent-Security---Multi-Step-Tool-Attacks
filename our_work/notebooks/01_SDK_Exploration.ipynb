# %% [markdown]
# # 01. SDK Exploration
# Welcome to the first notebook. In this section, we explore the structural APIs and models of the `aicomp_sdk`.

# %%
import sys
from pathlib import Path
project_root = Path('.').resolve().parent
sys.path.insert(0, str(project_root))
sys.path.insert(0, str(project_root / 'src'))

from aicomp_sdk.attacks.contracts import AttackCandidate, AttackRunConfig
print('Loaded SDK modules successfully!')
