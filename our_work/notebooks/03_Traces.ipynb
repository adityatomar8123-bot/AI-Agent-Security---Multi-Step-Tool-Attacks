# %% [markdown]
# # 03. Trace Hashing and Observations
# In this section, we extract trace histories and evaluate state cell hashes to build signature-based equivalence classes.

# %%
import sys
from pathlib import Path
project_root = Path('.').resolve().parent
sys.path.insert(0, str(project_root / 'src'))

import attack_discovery as ad
print('Loaded Attack Discovery Trace Utilities!')
