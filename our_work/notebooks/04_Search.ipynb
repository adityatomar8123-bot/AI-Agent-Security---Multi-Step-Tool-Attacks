# %% [markdown]
# # 04. Execution Search Trees
# This notebook tests the minimax alpha-beta search algorithm and state-space explorer trees.

# %%
import sys
from pathlib import Path
project_root = Path('.').resolve().parent
sys.path.insert(0, str(project_root / 'src'))

from stockfish_python import SearchEngine, Position
pos = Position()
pos.set_fen('rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1')
searcher = SearchEngine()
best_move, score = searcher.search(pos, max_depth=2)
print(f'Stockfish Best Move: {best_move} with score: {score}')
